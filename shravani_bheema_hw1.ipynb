# %% [markdown]
# BUS AN 511: Programming Essentials
# **Homework One**

# %% [markdown]
# **QUESTION 1**

# %%
a = float(input("Please enter the first number:"))
b = float(input("Please enter the second number:"))
c = float(input("Please enter the third number:"))
sum= a+b+c
print("The sum of the three numbers is " + str(sum))
# Out:
# Please enter the first number:3
# Please enter the second number:4
# Please enter the third number:5.5
# The sum of the three numbers is 12.5

# %% [markdown]
# **QUESTION 2**

# %%
a = 12
b = 16
x = a/b*15.3-16**4-84+96/3
print(x)
print(type(x))
# Out:
# -65576.525
# <class 'float'>

# %% [markdown]
# **QUESTION 3**

# %%
name = input("Please enter your name: ")
age = input("Please enter your age: ")
city = input("Please enter the name of the city where you currently live: ")
college = input("Please enter the name of your college: ")
profession = input("Please enter your profession: ")
print("There once was a person named " + name + " who lived in " + city +
".\n" + "At the age of " + age + ", " + name + " went to college at "
 + college + ".\n" + name + " graduated and went to work as a "
  + profession + " and lived happily ever after. ")
# Out:
# Please enter your name: Shravani
# Please enter your age: 25
# Please enter the name of the city where you currently live: Seattle
# Please enter the name of your college: The University of Washington
# Please enter your profession: data analyst
# There once was a person named Shravani who lived in Seattle.
# At the age of 25, Shravani went to college at The University of Washington.
# Shravani graduated and went to work as a data analyst and lived happily ever after.
